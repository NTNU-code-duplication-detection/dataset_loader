# %%
import json
import asyncio

import javalang

from data.dataset_factory import get_dataset_generator
from data.data_generators.schema import CodeSample
from preprocessing.comment_stripper import strip_java_comments
from preprocessing.embeddings import create_ast
from preprocessing.hier_split import hierarchical_split, hierarchical_split_2, linearize_ast_for_unixcoder
from preprocessing.java_ast_async import extract_classes_async, parse_and_extract_classes, flatten_ast, clean_chunk

from visualizer.serialize_ast import serialize_ast

# %%
# Get a random set of functions
gen = get_dataset_generator(
    dataset_name='sourcecodeplag',
    mode='plagiarized',
    **{}
    )

pair: CodeSample = next(gen)

code_a = pair.code_a
print(code_a)
# Out:
# import java.util.Scanner;
#
# public class T7 {
# 	public static void main(String[] args) {
# 		Scanner input = new Scanner(System.in);
#
# 		System.out.print("Enter a 4 by 4 matrix row by row: ");
# 		double[][] m = new double[4][4];
#
# 		for (int i = 0; i < 4; i++)
# 			for (int j = 0; j < 4; j++)
# 				m[i][j] = input.nextDouble();
#
# 		System.out.print("Sum of the elements in the major diagonal is " + sumMajorDiagonal(m));
# 	}
#
# 	public static double sumMajorDiagonal(double[][] m) {
# 		double sum = 0;
#
# 		for (int i = 0; i < m.length; i++)
# 			sum += m[i][i];
#
# 		return sum;
# 	}
#
# }

# %%
hierarchy = hierarchical_split_2(code_a)

print(json.dumps(hierarchy, indent=2, default=serialize_ast))
# Out:
# {
#   "method_name": "main",
#   "parameters": [
#     "args"
#   ],
#   "body": [
#     {
#       "type": "LocalVariableDeclaration",
#       "code": "input = ClassCreator(arguments=[MemberReference(member=in, postfix_operators=[], prefix_operators=[], qualifier=System, selectors=[])], body=None, constructor_type_arguments=None, postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], type=ReferenceType(arguments=None, dimensions=None, name=Scanner, sub_type=None));",
#       "ast_node": {
#         "modifiers": "set()",
#         "annotations": [],
#         "type": {
#           "name": "Scanner",
#           "dimensions": [],
#           "arguments": null,
#           "sub_type": null
#         },
#         "declarators": [
#           {
#             "name": "input",
#             "dimensions": [],
#             "initializer": {
#               "prefix_operators": [],
#               "postfix_operators": [],
#               "qualifier": null,
#               "selectors": [],
#               "type": {
#                 "name": "Scanner",
#                 "dimensions": null,
#                 "arguments": null,
#                 "sub_type": null
#               },
#               "constructor_type_arguments": null,
#               "arguments": [
#                 {
#                   "prefix_operators": [],
#                   "postfix_operators": [],
#                   "qualifier": "System",
#                   "selectors": [],
#                   "member": "in",
#                   "_position": [
#                     5,
#                     31
#                   ]
#                 }
#               ],
#               "body": null
#             }
#           }
#         ],
#         "_position": [
#           5,
#           3
#         ]
#       }
#     },
#     {
#       "type": "StatementExpression",
#       "code": "MethodInvocation(arguments=[Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=\"Enter a 4 by 4 matrix row by row: \")], member=print, postfix_operators=[], prefix_operators=[], qualifier=System.out, selectors=[], type_arguments=None)",
#       "ast_node": {
#         "label": null,
#         "expression": {
#           "prefix_operators": [],
#           "postfix_operators": [],
#           "qualifier": "System.out",
#           "selectors": [],
#           "type_arguments": null,
#           "arguments": [
#             {
#               "prefix_operators": [],
#               "postfix_operators": [],
#               "qualifier": null,
#               "selectors": [],
#               "value": "\"Enter a 4 by 4 matrix row by row: \"",
#               "_position": [
#                 7,
#                 20
#               ]
#             }
#           ],
#           "member": "print",
#           "_position": [
#             7,
#             3
#           ]
#         },
#         "_position": [
#           7,
#           3
#         ]
#       }
#     },
#     {
#       "type": "LocalVariableDeclaration",
#       "code": "m = ArrayCreator(dimensions=[Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=4), Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=4)], initializer=None, postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], type=BasicType(dimensions=None, name=double));",
#       "ast_node": {
#         "modifiers": "set()",
#         "annotations": [],
#         "type": {
#           "name": "double",
#           "dimensions": [
#             null,
#             null
#           ]
#         },
#         "declarators": [
#           {
#             "name": "m",
#             "dimensions": [],
#             "initializer": {
#               "prefix_operators": [],
#               "postfix_operators": [],
#               "qualifier": null,
#               "selectors": [],
#               "type": {
#                 "name": "double",
#                 "dimensions": null
#               },
#               "dimensions": [
#                 {
#                   "prefix_operators": [],
#                   "postfix_operators": [],
#                   "qualifier": null,
#                   "selectors": [],
#                   "value": "4",
#                   "_position": [
#                     8,
#                     29
#                   ]
#                 },
#                 {
#                   "prefix_operators": [],
#                   "postfix_operators": [],
#                   "qualifier": null,
#                   "selectors": [],
#                   "value": "4",
#                   "_position": [
#                     8,
#                     32
#                   ]
#                 }
#               ],
#               "initializer": null
#             }
#           }
#         ],
#         "_position": [
#           8,
#           3
#         ]
#       }
#     },
#     {
#       "type": "ForStatement",
#       "code": "for (ForControl(condition=BinaryOperation(operandl=MemberReference(member=i, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[]), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=4), operator=<), init=VariableDeclaration(annotations=[], declarators=[VariableDeclarator(dimensions=None, initializer=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=0), name=i)], modifiers=set(), type=BasicType(dimensions=[], name=int)), update=[MemberReference(member=i, postfix_operators=['++'], prefix_operators=[], qualifier=, selectors=[])])) { ... }",
#       "ast_node": {
#         "label": null,
#         "control": {
#           "init": {
#             "modifiers": "set()",
#             "annotations": [],
#             "type": {
#               "name": "int",
#               "dimensions": []
#             },
#             "declarators": [
#               {
#                 "name": "i",
#                 "dimensions": null,
#                 "initializer": {
#                   "prefix_operators": [],
#                   "postfix_operators": [],
#                   "qualifier": null,
#                   "selectors": [],
#                   "value": "0",
#                   "_position": [
#                     10,
#                     16
#                   ]
#                 }
#               }
#             ]
#           },
#           "condition": {
#             "operator": "<",
#             "operandl": {
#               "prefix_operators": [],
#               "postfix_operators": [],
#               "qualifier": "",
#               "selectors": [],
#               "member": "i",
#               "_position": [
#                 10,
#                 19
#               ]
#             },
#             "operandr": {
#               "prefix_operators": [],
#               "postfix_operators": [],
#               "qualifier": null,
#               "selectors": [],
#               "value": "4",
#               "_position": [
#                 10,
#                 23
#               ]
#             }
#           },
#           "update": [
#             {
#               "prefix_operators": [],
#               "postfix_operators": [
#                 "++"
#               ],
#               "qualifier": "",
#               "selectors": [],
#               "member": "i",
#               "_position": [
#                 10,
#                 26
#               ]
#             }
#           ]
#         },
#         "body": {
#           "label": null,
#           "control": {
#             "init": {
#               "modifiers": "set()",
#               "annotations": [],
#               "type": {
#                 "name": "int",
#                 "dimensions": []
#               },
#               "declarators": [
#                 {
#                   "name": "j",
#                   "dimensions": null,
#                   "initializer": {
#                     "prefix_operators": [],
#                     "postfix_operators": [],
#                     "qualifier": null,
#                     "selectors": [],
#                     "value": "0",
#                     "_position": [
#                       11,
#                       17
#                     ]
#                   }
#                 }
#               ]
#             },
#             "condition": {
#               "operator": "<",
#               "operandl": {
#                 "prefix_operators": [],
#                 "postfix_operators": [],
#                 "qualifier": "",
#                 "selectors": [],
#                 "member": "j",
#                 "_position": [
#                   11,
#                   20
#                 ]
#               },
#               "operandr": {
#                 "prefix_operators": [],
#                 "postfix_operators": [],
#                 "qualifier": null,
#                 "selectors": [],
#                 "value": "4",
#                 "_position": [
#                   11,
#                   24
#                 ]
#               }
#             },
#             "update": [
#               {
#                 "prefix_operators": [],
#                 "postfix_operators": [
#                   "++"
#                 ],
#                 "qualifier": "",
#                 "selectors": [],
#                 "member": "j",
#                 "_position": [
#                   11,
#                   27
#                 ]
#               }
#             ]
#           },
#           "body": {
#             "label": null,
#             "expression": {
#               "expressionl": {
#                 "prefix_operators": [],
#                 "postfix_operators": [],
#                 "qualifier": "",
#                 "selectors": [
#                   {
#                     "index": {
#                       "prefix_operators": [],
#                       "postfix_operators": [],
#                       "qualifier": "",
#                       "selectors": [],
#                       "member": "i",
#                       "_position": [
#                         12,
#                         7
#                       ]
#                     },
#                     "_position": [
#                       12,
#                       6
#                     ]
#                   },
#                   {
#                     "index": {
#                       "prefix_operators": [],
#                       "postfix_operators": [],
#                       "qualifier": "",
#                       "selectors": [],
#                       "member": "j",
#                       "_position": [
#                         12,
#                         10
#                       ]
#                     },
#                     "_position": [
#                       12,
#                       9
#                     ]
#                   }
#                 ],
#                 "member": "m",
#                 "_position": [
#                   12,
#                   5
#                 ]
#               },
#               "value": {
#                 "prefix_operators": [],
#                 "postfix_operators": [],
#                 "qualifier": "input",
#                 "selectors": [],
#                 "type_arguments": null,
#                 "arguments": [],
#                 "member": "nextDouble",
#                 "_position": [
#                   12,
#                   15
#                 ]
#               },
#               "type": "="
#             },
#             "_position": [
#               12,
#               5
#             ]
#           },
#           "_position": [
#             11,
#             4
#           ]
#         },
#         "_position": [
#           10,
#           3
#         ]
#       },
#       "body": [
#         {
#           "type": "ForStatement",
#           "code": "for (ForControl(condition=BinaryOperation(operandl=MemberReference(member=j, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[]), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=4), operator=<), init=VariableDeclaration(annotations=[], declarators=[VariableDeclarator(dimensions=None, initializer=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=0), name=j)], modifiers=set(), type=BasicType(dimensions=[], name=int)), update=[MemberReference(member=j, postfix_operators=['++'], prefix_operators=[], qualifier=, selectors=[])])) { ... }",
#           "ast_node": {
#             "label": null,
#             "control": {
#               "init": {
#                 "modifiers": "set()",
#                 "annotations": [],
#                 "type": {
#                   "name": "int",
#                   "dimensions": []
#                 },
#                 "declarators": [
#                   {
#                     "name": "j",
#                     "dimensions": null,
#                     "initializer": {
#                       "prefix_operators": [],
#                       "postfix_operators": [],
#                       "qualifier": null,
#                       "selectors": [],
#                       "value": "0",
#                       "_position": [
#                         11,
#                         17
#                       ]
#                     }
#                   }
#                 ]
#               },
#               "condition": {
#                 "operator": "<",
#                 "operandl": {
#                   "prefix_operators": [],
#                   "postfix_operators": [],
#                   "qualifier": "",
#                   "selectors": [],
#                   "member": "j",
#                   "_position": [
#                     11,
#                     20
#                   ]
#                 },
#                 "operandr": {
#                   "prefix_operators": [],
#                   "postfix_operators": [],
#                   "qualifier": null,
#                   "selectors": [],
#                   "value": "4",
#                   "_position": [
#                     11,
#                     24
#                   ]
#                 }
#               },
#               "update": [
#                 {
#                   "prefix_operators": [],
#                   "postfix_operators": [
#                     "++"
#                   ],
#                   "qualifier": "",
#                   "selectors": [],
#                   "member": "j",
#                   "_position": [
#                     11,
#                     27
#                   ]
#                 }
#               ]
#             },
#             "body": {
#               "label": null,
#               "expression": {
#                 "expressionl": {
#                   "prefix_operators": [],
#                   "postfix_operators": [],
#                   "qualifier": "",
#                   "selectors": [
#                     {
#                       "index": {
#                         "prefix_operators": [],
#                         "postfix_operators": [],
#                         "qualifier": "",
#                         "selectors": [],
#                         "member": "i",
#                         "_position": [
#                           12,
#                           7
#                         ]
#                       },
#                       "_position": [
#                         12,
#                         6
#                       ]
#                     },
#                     {
#                       "index": {
#                         "prefix_operators": [],
#                         "postfix_operators": [],
#                         "qualifier": "",
#                         "selectors": [],
#                         "member": "j",
#                         "_position": [
#                           12,
#                           10
#                         ]
#                       },
#                       "_position": [
#                         12,
#                         9
#                       ]
#                     }
#                   ],
#                   "member": "m",
#                   "_position": [
#                     12,
#                     5
#                   ]
#                 },
#                 "value": {
#                   "prefix_operators": [],
#                   "postfix_operators": [],
#                   "qualifier": "input",
#                   "selectors": [],
#                   "type_arguments": null,
#                   "arguments": [],
#                   "member": "nextDouble",
#                   "_position": [
#                     12,
#                     15
#                   ]
#                 },
#                 "type": "="
#               },
#               "_position": [
#                 12,
#                 5
#               ]
#             },
#             "_position": [
#               11,
#               4
#             ]
#           },
#           "body": [
#             {
#               "type": "StatementExpression",
#               "code": "Assignment(expressionl=MemberReference(member=m, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[ArraySelector(index=MemberReference(member=i, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[])), ArraySelector(index=MemberReference(member=j, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[]))]), type==, value=MethodInvocation(arguments=[], member=nextDouble, postfix_operators=[], prefix_operators=[], qualifier=input, selectors=[], type_arguments=None))",
#               "ast_node": {
#                 "label": null,
#                 "expression": {
#                   "expressionl": {
#                     "prefix_operators": [],
#                     "postfix_operators": [],
#                     "qualifier": "",
#                     "selectors": [
#                       {
#                         "index": {
#                           "prefix_operators": [],
#                           "postfix_operators": [],
#                           "qualifier": "",
#                           "selectors": [],
#                           "member": "i",
#                           "_position": [
#                             12,
#                             7
#                           ]
#                         },
#                         "_position": [
#                           12,
#                           6
#                         ]
#                       },
#                       {
#                         "index": {
#                           "prefix_operators": [],
#                           "postfix_operators": [],
#                           "qualifier": "",
#                           "selectors": [],
#                           "member": "j",
#                           "_position": [
#                             12,
#                             10
#                           ]
#                         },
#                         "_position": [
#                           12,
#                           9
#                         ]
#                       }
#                     ],
#                     "member": "m",
#                     "_position": [
#                       12,
#                       5
#                     ]
#                   },
#                   "value": {
#                     "prefix_operators": [],
#                     "postfix_operators": [],
#                     "qualifier": "input",
#                     "selectors": [],
#                     "type_arguments": null,
#                     "arguments": [],
#                     "member": "nextDouble",
#                     "_position": [
#                       12,
#                       15
#                     ]
#                   },
#                   "type": "="
#                 },
#                 "_position": [
#                   12,
#                   5
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "StatementExpression",
#       "code": "MethodInvocation(arguments=[BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=\"Sum of the elements in the major diagonal is \"), operandr=MethodInvocation(arguments=[MemberReference(member=m, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[])], member=sumMajorDiagonal, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[], type_arguments=None), operator=+)], member=print, postfix_operators=[], prefix_operators=[], qualifier=System.out, selectors=[], type_arguments=None)",
#       "ast_node": {
#         "label": null,
#         "expression": {
#           "prefix_operators": [],
#           "postfix_operators": [],
#           "qualifier": "System.out",
#           "selectors": [],
#           "type_arguments": null,
#           "arguments": [
#             {
#               "operator": "+",
#               "operandl": {
#                 "prefix_operators": [],
#                 "postfix_operators": [],
#                 "qualifier": null,
#                 "selectors": [],
#                 "value": "\"Sum of the elements in the major diagonal is \"",
#                 "_position": [
#                   14,
#                   20
#                 ]
#               },
#               "operandr": {
#                 "prefix_operators": [],
#                 "postfix_operators": [],
#                 "qualifier": "",
#                 "selectors": [],
#                 "type_arguments": null,
#                 "arguments": [
#                   {
#                     "prefix_operators": [],
#                     "postfix_operators": [],
#                     "qualifier": "",
#                     "selectors": [],
#                     "member": "m",
#                     "_position": [
#                       14,
#                       87
#                     ]
#                   }
#                 ],
#                 "member": "sumMajorDiagonal",
#                 "_position": [
#                   14,
#                   70
#                 ]
#               }
#             }
#           ],
#           "member": "print",
#           "_position": [
#             14,
#             3
#           ]
#         },
#         "_position": [
#           14,
#           3
#         ]
#       }
#     }
#   ]
# }

# %% [markdown]
# # Function chunking
# Reduce functions into meaningful parts with its assigned CHunk metadata (AST in this case)

# %%
chunks = flatten_ast(hierarchy)
for i, chunk in enumerate(chunks, 1):
    cleaned_chunk = clean_chunk(chunk)
    print(f"Chunk {i}:\n{cleaned_chunk}\n---")
# Out:
# Chunk 1:
# input = ClassCreator(arguments=[in], , , , , , , type=ReferenceType(, , name=Scanner, ));
# ---
# Chunk 2:
# MethodInvocation(arguments=["Enter a 4 by 4 matrix row by row: "], member=print, , , System.out, , )
# ---
# Chunk 3:
# m = ArrayCreator(dimensions=[4, 4], , , , , , type=BasicType(, name=double));
# ---
# Chunk 4:
# for (ForControl(condition=BinaryOperation(operandl=i, operandr=4, operator=<), init=VariableDeclaration(, declarators=[VariableDeclarator(, initializer=0, name=i)], modifiers=set(), type=BasicType(dimensions=[], name=int)), update=[i])) { ... }
# ---
# Chunk 5:
# for (ForControl(condition=BinaryOperation(operandl=j, operandr=4, operator=<), init=VariableDeclaration(, declarators=[VariableDeclarator(, initializer=0, name=j)], modifiers=set(), type=BasicType(dimensions=[], name=int)), update=[j])) { ... }
# ---
# Chunk 6:
# Assignment(expressionl=m), ArraySelector(index=j)]), type==, value=MethodInvocation(arguments=[], member=nextDouble, , , input, , ))
# ---
# Chunk 7:
# MethodInvocation(arguments=[BinaryOperation(operandl="Sum of the elements in the major diagonal is ", operandr=MethodInvocation(arguments=[m], member=sumMajorDiagonal, , , qualifier=, , ), operator=+)], member=print, , , System.out, , )
# ---
